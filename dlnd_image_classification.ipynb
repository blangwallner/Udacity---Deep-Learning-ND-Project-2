# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# CIFAR-10 Dataset: 171MB [00:49, 3.41MB/s]
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 2
sample_id = 15
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 15:
# Image - Min Value: 1 Max Value: 225
# Image - Shape: (32, 32, 3)
# Label - Label Id: 4 Name: deer

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    result = np.array(x,dtype=float)/255.
    return result


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    onehot = np.zeros((len(x),10))
    onehot[range(len(x)),x] = 1
    return onehot


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# If you're finding it hard to dedicate enough time for this course a week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) to build each layer, except "Convolutional & Max Pooling" layer.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# If you would like to get the most of this course, try to solve all the problems without TF Layers.  Let's begin!
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    input_data = tf.placeholder(tf.float32, shape=(None, image_shape[0], image_shape[1], image_shape[2]), name="x")
    return input_data


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    input_labels = tf.placeholder(tf.float32, shape=(None, n_classes), name="y")
    return input_labels


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    keep_prob = tf.placeholder(tf.float32, name="keep_prob")
    return keep_prob


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# Note: You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.  You're free to use any TensorFlow package for all the other layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    padding = "SAME"
    
    # convolutional layer
    x_shape = x_tensor.get_shape().as_list()
    input_dims = x_shape[-1]
    # choose a std_dev < 1 to spread out the weights more
    W = tf.Variable(tf.truncated_normal((conv_ksize[0],conv_ksize[1],input_dims,conv_num_outputs),stddev=0.1))
    b = tf.Variable(tf.zeros(conv_num_outputs))
    conv_strides_vec = [1, conv_strides[0], conv_strides[1], 1]
    
    conv_layer_output = tf.nn.conv2d(x_tensor, W, conv_strides_vec, padding) + b
    conv_layer_output = tf.nn.relu(conv_layer_output)
    
    # Max pool layer
    pool_strides_vec = [1,pool_strides[0], pool_strides[1], 1]
    pool_ksize_vec = [1, conv_ksize[0], conv_ksize[1], 1]
    
    pool_layer_output = tf.nn.max_pool(conv_layer_output, pool_ksize_vec, pool_strides_vec, padding)
    return pool_layer_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    x_shape = x_tensor.get_shape().as_list()
    dims = x_shape[1]*x_shape[2]*x_shape[3]
    flattened_x = tf.reshape(x_tensor, [-1, dims])
    return flattened_x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    x_shape = x_tensor.get_shape().as_list()
    n_input = x_shape[1]
    W = tf.Variable(tf.truncated_normal((n_input, num_outputs),stddev=0.1))
    b = tf.Variable(tf.zeros(num_outputs))
    output = tf.nn.relu(tf.matmul(x_tensor, W) + b)
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). You can use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for this layer.
#
# Note: Activation, softmax, or cross entropy shouldn't be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    x_shape = x_tensor.get_shape().as_list()
    n_input = x_shape[1]
    W = tf.Variable(tf.truncated_normal((n_input, num_outputs),stddev=0.1))
    b = tf.Variable(tf.zeros(num_outputs))
    output = tf.add(tf.matmul(x_tensor, W), b)
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    # Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #x = conv2d_maxpool(x, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    x = conv2d_maxpool(x, 16, [4,4], [1,1], [3,3], [2,2])
    x = tf.nn.dropout(x,keep_prob)
    x = conv2d_maxpool(x, 32, [3,3], [2,2], [3,3], [2,2])
    # x = conv2d_maxpool(x, 64, [3,3], [3,3], [3,3], [3,3])
    x = tf.nn.dropout(x,keep_prob)
    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    x = flatten(x)
    

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #x = fully_conn(x, num_outputs)
    x = fully_conn(x, 128)
    x = fully_conn(x, 32)
   
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    x = output(x, 10)
    
    
    # TODO: return output
    return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    feed_dict = {x: feature_batch, y: label_batch, keep_prob:keep_probability}
    session.run(optimizer, feed_dict=feed_dict)
    pass


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    train_feed_dict = {x: feature_batch, y: label_batch, keep_prob:1.}
    valid_feed_dict = {x: valid_features, y: valid_labels, keep_prob:1.}
    train_cost, train_acc = session.run([cost, accuracy], feed_dict=train_feed_dict)
    valid_cost, valid_acc = session.run([cost, accuracy], feed_dict=valid_feed_dict)
    print("Train cost: {:.3f}, train acc: {:.3f}, validation cost: {:.3f}, validation acc: {:.3f}".format(train_cost,train_acc, valid_cost, valid_acc))
    pass

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 40
batch_size = 128
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Train cost: 2.251, train acc: 0.100, validation cost: 2.205, validation acc: 0.245
# Epoch  2, CIFAR-10 Batch 1:  Train cost: 2.165, train acc: 0.175, validation cost: 1.974, validation acc: 0.273
# Epoch  3, CIFAR-10 Batch 1:  Train cost: 2.066, train acc: 0.250, validation cost: 1.783, validation acc: 0.354
# Epoch  4, CIFAR-10 Batch 1:  Train cost: 1.973, train acc: 0.325, validation cost: 1.691, validation acc: 0.387
# Epoch  5, CIFAR-10 Batch 1:  Train cost: 1.910, train acc: 0.325, validation cost: 1.626, validation acc: 0.415
# Epoch  6, CIFAR-10 Batch 1:  Train cost: 1.845, train acc: 0.350, validation cost: 1.600, validation acc: 0.429
# Epoch  7, CIFAR-10 Batch 1:  Train cost: 1.791, train acc: 0.325, validation cost: 1.568, validation acc: 0.442
# Epoch  8, CIFAR-10 Batch 1:  Train cost: 1.746, train acc: 0.350, validation cost: 1.537, validation acc: 0.448
# Epoch  9, CIFAR-10 Batch 1:  Train cost: 1.702, train acc: 0.400, validation cost: 1.531, validation acc: 0.460
# Epoch 10, CIFAR-10 Batch 1:  Train cost: 1.642, train acc: 0.425, validation cost: 1.500, validation acc: 0.468
# Epoch 11, CIFAR-10 Batch 1:  Train cost: 1.618, train acc: 0.450, validation cost: 1.497, validation acc: 0.479
# Epoch 12, CIFAR-10 Batch 1:  Train cost: 1.624, train acc: 0.425, validation cost: 1.476, validation acc: 0.482
# Epoch 13, CIFAR-10 Batch 1:  Train cost: 1.594, train acc: 0.500, validation cost: 1.476, validation acc: 0.476
# Epoch 14, CIFAR-10 Batch 1:  Train cost: 1.548, train acc: 0.475, validation cost: 1.452, validation acc: 0.493
# Epoch 15, CIFAR-10 Batch 1:  Train cost: 1.514, train acc: 0.475, validation cost: 1.433, validation acc: 0.498
# Epoch 16, CIFAR-10 Batch 1:  Train cost: 1.479, train acc: 0.500, validation cost: 1.429, validation acc: 0.502
# Epoch 17, CIFAR-10 Batch 1:  Train cost: 1.467, train acc: 0.475, validation cost: 1.412, validation acc: 0.505
# Epoch 18, CIFAR-10 Batch 1:  Train cost: 1.430, train acc: 0.500, validation cost: 1.413, validation acc: 0.501
# Epoch 19, CIFAR-10 Batch 1:  Train cost: 1.425, train acc: 0.525, validation cost: 1.402, validation acc: 0.507
# Epoch 20, CIFAR-10 Batch 1:  Train cost: 1.385, train acc: 0.525, validation cost: 1.382, validation acc: 0.515
# Epoch 21, CIFAR-10 Batch 1:  Train cost: 1.359, train acc: 0.575, validation cost: 1.383, validation acc: 0.509
# Epoch 22, CIFAR-10 Batch 1:  Train cost: 1.345, train acc: 0.575, validation cost: 1.361, validation acc: 0.525
# Epoch 23, CIFAR-10 Batch 1:  Train cost: 1.311, train acc: 0.600, validation cost: 1.357, validation acc: 0.530
# Epoch 24, CIFAR-10 Batch 1:  Train cost: 1.279, train acc: 0.625, validation cost: 1.359, validation acc: 0.529
# Epoch 25, CIFAR-10 Batch 1:  Train cost: 1.280, train acc: 0.600, validation cost: 1.354, validation acc: 0.526
# Epoch 26, CIFAR-10 Batch 1:  Train cost: 1.270, train acc: 0.550, validation cost: 1.350, validation acc: 0.530
# Epoch 27, CIFAR-10 Batch 1:  Train cost: 1.258, train acc: 0.625, validation cost: 1.342, validation acc: 0.531
# Epoch 28, CIFAR-10 Batch 1:  Train cost: 1.220, train acc: 0.600, validation cost: 1.329, validation acc: 0.539
# Epoch 29, CIFAR-10 Batch 1:  Train cost: 1.211, train acc: 0.600, validation cost: 1.325, validation acc: 0.535
# Epoch 30, CIFAR-10 Batch 1:  Train cost: 1.213, train acc: 0.650, validation cost: 1.322, validation acc: 0.550
# Epoch 31, CIFAR-10 Batch 1:  Train cost: 1.169, train acc: 0.625, validation cost: 1.314, validation acc: 0.546
# Epoch 32, CIFAR-10 Batch 1:  Train cost: 1.143, train acc: 0.675, validation cost: 1.310, validation acc: 0.546
# Epoch 33, CIFAR-10 Batch 1:  Train cost: 1.140, train acc: 0.650, validation cost: 1.290, validation acc: 0.548
# Epoch 34, CIFAR-10 Batch 1:  Train cost: 1.133, train acc: 0.650, validation cost: 1.303, validation acc: 0.551
# Epoch 35, CIFAR-10 Batch 1:  Train cost: 1.094, train acc: 0.650, validation cost: 1.285, validation acc: 0.563
# Epoch 36, CIFAR-10 Batch 1:  Train cost: 1.098, train acc: 0.650, validation cost: 1.290, validation acc: 0.556
# Epoch 37, CIFAR-10 Batch 1:  Train cost: 1.102, train acc: 0.675, validation cost: 1.283, validation acc: 0.555
# Epoch 38, CIFAR-10 Batch 1:  Train cost: 1.076, train acc: 0.700, validation cost: 1.274, validation acc: 0.563
# Epoch 39, CIFAR-10 Batch 1:  Train cost: 1.066, train acc: 0.650, validation cost: 1.281, validation acc: 0.559
# Epoch 40, CIFAR-10 Batch 1:  Train cost: 1.050, train acc: 0.650, validation cost: 1.264, validation acc: 0.567

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Train cost: 2.236, train acc: 0.200, validation cost: 2.191, validation acc: 0.203
# Epoch  1, CIFAR-10 Batch 2:  Train cost: 2.093, train acc: 0.275, validation cost: 2.022, validation acc: 0.272
# Epoch  1, CIFAR-10 Batch 3:  Train cost: 1.855, train acc: 0.250, validation cost: 1.922, validation acc: 0.302
# Epoch  1, CIFAR-10 Batch 4:  Train cost: 1.814, train acc: 0.350, validation cost: 1.789, validation acc: 0.372
# Epoch  1, CIFAR-10 Batch 5:  Train cost: 1.750, train acc: 0.400, validation cost: 1.730, validation acc: 0.379
# Epoch  2, CIFAR-10 Batch 1:  Train cost: 1.876, train acc: 0.375, validation cost: 1.669, validation acc: 0.417
# Epoch  2, CIFAR-10 Batch 2:  Train cost: 1.687, train acc: 0.450, validation cost: 1.636, validation acc: 0.425
# Epoch  2, CIFAR-10 Batch 3:  Train cost: 1.544, train acc: 0.400, validation cost: 1.633, validation acc: 0.421
# Epoch  2, CIFAR-10 Batch 4:  Train cost: 1.726, train acc: 0.350, validation cost: 1.590, validation acc: 0.442
# Epoch  2, CIFAR-10 Batch 5:  Train cost: 1.604, train acc: 0.400, validation cost: 1.589, validation acc: 0.438
# Epoch  3, CIFAR-10 Batch 1:  Train cost: 1.774, train acc: 0.325, validation cost: 1.533, validation acc: 0.467
# Epoch  3, CIFAR-10 Batch 2:  Train cost: 1.514, train acc: 0.500, validation cost: 1.507, validation acc: 0.474
# Epoch  3, CIFAR-10 Batch 3:  Train cost: 1.417, train acc: 0.550, validation cost: 1.493, validation acc: 0.483
# Epoch  3, CIFAR-10 Batch 4:  Train cost: 1.609, train acc: 0.375, validation cost: 1.488, validation acc: 0.476
# Epoch  3, CIFAR-10 Batch 5:  Train cost: 1.532, train acc: 0.475, validation cost: 1.507, validation acc: 0.474
# Epoch  4, CIFAR-10 Batch 1:  Train cost: 1.651, train acc: 0.400, validation cost: 1.440, validation acc: 0.498
# Epoch  4, CIFAR-10 Batch 2:  Train cost: 1.475, train acc: 0.475, validation cost: 1.440, validation acc: 0.497
# Epoch  4, CIFAR-10 Batch 3:  Train cost: 1.333, train acc: 0.550, validation cost: 1.456, validation acc: 0.491
# Epoch  4, CIFAR-10 Batch 4:  Train cost: 1.520, train acc: 0.425, validation cost: 1.427, validation acc: 0.495
# Epoch  4, CIFAR-10 Batch 5:  Train cost: 1.477, train acc: 0.500, validation cost: 1.449, validation acc: 0.485
# Epoch  5, CIFAR-10 Batch 1:  Train cost: 1.596, train acc: 0.500, validation cost: 1.417, validation acc: 0.495
# Epoch  5, CIFAR-10 Batch 2:  Train cost: 1.444, train acc: 0.475, validation cost: 1.404, validation acc: 0.501
# Epoch  5, CIFAR-10 Batch 3:  Train cost: 1.307, train acc: 0.550, validation cost: 1.414, validation acc: 0.503
# Epoch  5, CIFAR-10 Batch 4:  Train cost: 1.489, train acc: 0.425, validation cost: 1.413, validation acc: 0.501
# Epoch  5, CIFAR-10 Batch 5:  Train cost: 1.449, train acc: 0.500, validation cost: 1.438, validation acc: 0.489
# Epoch  6, CIFAR-10 Batch 1:  Train cost: 1.537, train acc: 0.550, validation cost: 1.363, validation acc: 0.529
# Epoch  6, CIFAR-10 Batch 2:  Train cost: 1.406, train acc: 0.475, validation cost: 1.379, validation acc: 0.510
# Epoch  6, CIFAR-10 Batch 3:  Train cost: 1.247, train acc: 0.600, validation cost: 1.363, validation acc: 0.515
# Epoch  6, CIFAR-10 Batch 4:  Train cost: 1.401, train acc: 0.450, validation cost: 1.358, validation acc: 0.522
# Epoch  6, CIFAR-10 Batch 5:  Train cost: 1.364, train acc: 0.600, validation cost: 1.349, validation acc: 0.530
# Epoch  7, CIFAR-10 Batch 1:  Train cost: 1.462, train acc: 0.525, validation cost: 1.333, validation acc: 0.532
# Epoch  7, CIFAR-10 Batch 2:  Train cost: 1.385, train acc: 0.475, validation cost: 1.325, validation acc: 0.526
# Epoch  7, CIFAR-10 Batch 3:  Train cost: 1.225, train acc: 0.550, validation cost: 1.341, validation acc: 0.517
# Epoch  7, CIFAR-10 Batch 4:  Train cost: 1.345, train acc: 0.475, validation cost: 1.321, validation acc: 0.534
# Epoch  7, CIFAR-10 Batch 5:  Train cost: 1.345, train acc: 0.575, validation cost: 1.331, validation acc: 0.529
# Epoch  8, CIFAR-10 Batch 1:  Train cost: 1.416, train acc: 0.525, validation cost: 1.305, validation acc: 0.544
# Epoch  8, CIFAR-10 Batch 2:  Train cost: 1.374, train acc: 0.525, validation cost: 1.322, validation acc: 0.533
# Epoch  8, CIFAR-10 Batch 3:  Train cost: 1.155, train acc: 0.600, validation cost: 1.324, validation acc: 0.531
# Epoch  8, CIFAR-10 Batch 4:  Train cost: 1.280, train acc: 0.475, validation cost: 1.302, validation acc: 0.542
# Epoch  8, CIFAR-10 Batch 5:  Train cost: 1.365, train acc: 0.525, validation cost: 1.333, validation acc: 0.532
# Epoch  9, CIFAR-10 Batch 1:  Train cost: 1.345, train acc: 0.575, validation cost: 1.276, validation acc: 0.559
# Epoch  9, CIFAR-10 Batch 2:  Train cost: 1.324, train acc: 0.475, validation cost: 1.266, validation acc: 0.553
# Epoch  9, CIFAR-10 Batch 3:  Train cost: 1.102, train acc: 0.575, validation cost: 1.285, validation acc: 0.545
# Epoch  9, CIFAR-10 Batch 4:  Train cost: 1.288, train acc: 0.550, validation cost: 1.269, validation acc: 0.566
# Epoch  9, CIFAR-10 Batch 5:  Train cost: 1.290, train acc: 0.550, validation cost: 1.283, validation acc: 0.552
# Epoch 10, CIFAR-10 Batch 1:  Train cost: 1.312, train acc: 0.575, validation cost: 1.239, validation acc: 0.565
# Epoch 10, CIFAR-10 Batch 2:  Train cost: 1.300, train acc: 0.500, validation cost: 1.229, validation acc: 0.565
# Epoch 10, CIFAR-10 Batch 3:  Train cost: 1.100, train acc: 0.600, validation cost: 1.252, validation acc: 0.552
# Epoch 10, CIFAR-10 Batch 4:  Train cost: 1.270, train acc: 0.575, validation cost: 1.240, validation acc: 0.562
# Epoch 10, CIFAR-10 Batch 5:  Train cost: 1.228, train acc: 0.575, validation cost: 1.239, validation acc: 0.560
# Epoch 11, CIFAR-10 Batch 1:  Train cost: 1.308, train acc: 0.500, validation cost: 1.232, validation acc: 0.568
# Epoch 11, CIFAR-10 Batch 2:  Train cost: 1.257, train acc: 0.625, validation cost: 1.239, validation acc: 0.566
# Epoch 11, CIFAR-10 Batch 3:  Train cost: 1.092, train acc: 0.600, validation cost: 1.242, validation acc: 0.563
# Epoch 11, CIFAR-10 Batch 4:  Train cost: 1.186, train acc: 0.525, validation cost: 1.201, validation acc: 0.577
# Epoch 11, CIFAR-10 Batch 5:  Train cost: 1.213, train acc: 0.600, validation cost: 1.239, validation acc: 0.557
# Epoch 12, CIFAR-10 Batch 1:  Train cost: 1.243, train acc: 0.600, validation cost: 1.190, validation acc: 0.591
# Epoch 12, CIFAR-10 Batch 2:  Train cost: 1.246, train acc: 0.575, validation cost: 1.208, validation acc: 0.576
# Epoch 12, CIFAR-10 Batch 3:  Train cost: 1.027, train acc: 0.650, validation cost: 1.199, validation acc: 0.572
# Epoch 12, CIFAR-10 Batch 4:  Train cost: 1.182, train acc: 0.525, validation cost: 1.195, validation acc: 0.587
# Epoch 12, CIFAR-10 Batch 5:  Train cost: 1.188, train acc: 0.550, validation cost: 1.217, validation acc: 0.572
# Epoch 13, CIFAR-10 Batch 1:  Train cost: 1.238, train acc: 0.575, validation cost: 1.183, validation acc: 0.584
# Epoch 13, CIFAR-10 Batch 2:  Train cost: 1.225, train acc: 0.600, validation cost: 1.179, validation acc: 0.587
# Epoch 13, CIFAR-10 Batch 3:  Train cost: 1.036, train acc: 0.575, validation cost: 1.207, validation acc: 0.573
# Epoch 13, CIFAR-10 Batch 4:  Train cost: 1.208, train acc: 0.550, validation cost: 1.172, validation acc: 0.587
# Epoch 13, CIFAR-10 Batch 5:  Train cost: 1.144, train acc: 0.575, validation cost: 1.176, validation acc: 0.577
# Epoch 14, CIFAR-10 Batch 1:  Train cost: 1.209, train acc: 0.675, validation cost: 1.175, validation acc: 0.591
# Epoch 14, CIFAR-10 Batch 2:  Train cost: 1.194, train acc: 0.600, validation cost: 1.167, validation acc: 0.584
# Epoch 14, CIFAR-10 Batch 3:  Train cost: 1.028, train acc: 0.600, validation cost: 1.187, validation acc: 0.579
# Epoch 14, CIFAR-10 Batch 4:  Train cost: 1.106, train acc: 0.600, validation cost: 1.179, validation acc: 0.587
# Epoch 14, CIFAR-10 Batch 5:  Train cost: 1.102, train acc: 0.625, validation cost: 1.187, validation acc: 0.583
# Epoch 15, CIFAR-10 Batch 1:  Train cost: 1.128, train acc: 0.625, validation cost: 1.124, validation acc: 0.609
# Epoch 15, CIFAR-10 Batch 2:  Train cost: 1.123, train acc: 0.625, validation cost: 1.146, validation acc: 0.594
# Epoch 15, CIFAR-10 Batch 3:  Train cost: 1.007, train acc: 0.625, validation cost: 1.191, validation acc: 0.575
# Epoch 15, CIFAR-10 Batch 4:  Train cost: 1.111, train acc: 0.550, validation cost: 1.159, validation acc: 0.596
# Epoch 15, CIFAR-10 Batch 5:  Train cost: 1.076, train acc: 0.600, validation cost: 1.171, validation acc: 0.586
# Epoch 16, CIFAR-10 Batch 1:  Train cost: 1.181, train acc: 0.600, validation cost: 1.158, validation acc: 0.602
# Epoch 16, CIFAR-10 Batch 2:  Train cost: 1.210, train acc: 0.625, validation cost: 1.146, validation acc: 0.590
# Epoch 16, CIFAR-10 Batch 3:  Train cost: 1.008, train acc: 0.625, validation cost: 1.153, validation acc: 0.596
# Epoch 16, CIFAR-10 Batch 4:  Train cost: 1.164, train acc: 0.550, validation cost: 1.164, validation acc: 0.593
# Epoch 16, CIFAR-10 Batch 5:  Train cost: 1.040, train acc: 0.625, validation cost: 1.134, validation acc: 0.605
# Epoch 17, CIFAR-10 Batch 1:  Train cost: 1.106, train acc: 0.650, validation cost: 1.105, validation acc: 0.616
# Epoch 17, CIFAR-10 Batch 2:  Train cost: 1.199, train acc: 0.625, validation cost: 1.126, validation acc: 0.604
# Epoch 17, CIFAR-10 Batch 3:  Train cost: 0.945, train acc: 0.650, validation cost: 1.132, validation acc: 0.601
# Epoch 17, CIFAR-10 Batch 4:  Train cost: 1.074, train acc: 0.575, validation cost: 1.128, validation acc: 0.603
# Epoch 17, CIFAR-10 Batch 5:  Train cost: 1.057, train acc: 0.675, validation cost: 1.149, validation acc: 0.602
# Epoch 18, CIFAR-10 Batch 1:  Train cost: 1.066, train acc: 0.675, validation cost: 1.125, validation acc: 0.599
# Epoch 18, CIFAR-10 Batch 2:  Train cost: 1.091, train acc: 0.700, validation cost: 1.109, validation acc: 0.609
# Epoch 18, CIFAR-10 Batch 3:  Train cost: 0.989, train acc: 0.550, validation cost: 1.111, validation acc: 0.607
# Epoch 18, CIFAR-10 Batch 4:  Train cost: 1.044, train acc: 0.600, validation cost: 1.095, validation acc: 0.620
# Epoch 18, CIFAR-10 Batch 5:  Train cost: 0.999, train acc: 0.700, validation cost: 1.109, validation acc: 0.607
# Epoch 19, CIFAR-10 Batch 1:  Train cost: 1.126, train acc: 0.650, validation cost: 1.131, validation acc: 0.607
# Epoch 19, CIFAR-10 Batch 2:  Train cost: 1.093, train acc: 0.750, validation cost: 1.085, validation acc: 0.617
# Epoch 19, CIFAR-10 Batch 3:  Train cost: 0.994, train acc: 0.575, validation cost: 1.125, validation acc: 0.606
# Epoch 19, CIFAR-10 Batch 4:  Train cost: 1.090, train acc: 0.600, validation cost: 1.131, validation acc: 0.598
# Epoch 19, CIFAR-10 Batch 5:  Train cost: 0.982, train acc: 0.675, validation cost: 1.083, validation acc: 0.620
# Epoch 20, CIFAR-10 Batch 1:  Train cost: 1.040, train acc: 0.650, validation cost: 1.076, validation acc: 0.620
# Epoch 20, CIFAR-10 Batch 2:  Train cost: 1.068, train acc: 0.700, validation cost: 1.096, validation acc: 0.618
# Epoch 20, CIFAR-10 Batch 3:  Train cost: 0.948, train acc: 0.625, validation cost: 1.095, validation acc: 0.617
# Epoch 20, CIFAR-10 Batch 4:  Train cost: 1.094, train acc: 0.550, validation cost: 1.111, validation acc: 0.607
# Epoch 20, CIFAR-10 Batch 5:  Train cost: 0.964, train acc: 0.675, validation cost: 1.065, validation acc: 0.626
# Epoch 21, CIFAR-10 Batch 1:  Train cost: 1.085, train acc: 0.600, validation cost: 1.085, validation acc: 0.621
# Epoch 21, CIFAR-10 Batch 2:  Train cost: 1.030, train acc: 0.675, validation cost: 1.077, validation acc: 0.620
# Epoch 21, CIFAR-10 Batch 3:  Train cost: 0.905, train acc: 0.650, validation cost: 1.062, validation acc: 0.622
# Epoch 21, CIFAR-10 Batch 4:  Train cost: 0.988, train acc: 0.625, validation cost: 1.072, validation acc: 0.625
# Epoch 21, CIFAR-10 Batch 5:  Train cost: 0.935, train acc: 0.700, validation cost: 1.052, validation acc: 0.628
# Epoch 22, CIFAR-10 Batch 1:  Train cost: 1.060, train acc: 0.650, validation cost: 1.065, validation acc: 0.620
# Epoch 22, CIFAR-10 Batch 2:  Train cost: 1.051, train acc: 0.700, validation cost: 1.074, validation acc: 0.628
# Epoch 22, CIFAR-10 Batch 3:  Train cost: 0.956, train acc: 0.600, validation cost: 1.088, validation acc: 0.613
# Epoch 22, CIFAR-10 Batch 4:  Train cost: 0.998, train acc: 0.625, validation cost: 1.057, validation acc: 0.628
# Epoch 22, CIFAR-10 Batch 5:  Train cost: 0.930, train acc: 0.725, validation cost: 1.045, validation acc: 0.626
# Epoch 23, CIFAR-10 Batch 1:  Train cost: 1.016, train acc: 0.650, validation cost: 1.053, validation acc: 0.624
# Epoch 23, CIFAR-10 Batch 2:  Train cost: 1.041, train acc: 0.625, validation cost: 1.042, validation acc: 0.637
# Epoch 23, CIFAR-10 Batch 3:  Train cost: 0.977, train acc: 0.625, validation cost: 1.096, validation acc: 0.611
# Epoch 23, CIFAR-10 Batch 4:  Train cost: 1.029, train acc: 0.650, validation cost: 1.077, validation acc: 0.623
# Epoch 23, CIFAR-10 Batch 5:  Train cost: 0.939, train acc: 0.675, validation cost: 1.054, validation acc: 0.627
# Epoch 24, CIFAR-10 Batch 1:  Train cost: 0.977, train acc: 0.625, validation cost: 1.032, validation acc: 0.643
# Epoch 24, CIFAR-10 Batch 2:  Train cost: 1.068, train acc: 0.650, validation cost: 1.069, validation acc: 0.623
# Epoch 24, CIFAR-10 Batch 3:  Train cost: 0.898, train acc: 0.650, validation cost: 1.045, validation acc: 0.627
# Epoch 24, CIFAR-10 Batch 4:  Train cost: 0.948, train acc: 0.650, validation cost: 1.058, validation acc: 0.634
# Epoch 24, CIFAR-10 Batch 5:  Train cost: 0.939, train acc: 0.650, validation cost: 1.055, validation acc: 0.634
# Epoch 25, CIFAR-10 Batch 1:  Train cost: 0.987, train acc: 0.600, validation cost: 1.050, validation acc: 0.621
# Epoch 25, CIFAR-10 Batch 2:  Train cost: 1.043, train acc: 0.625, validation cost: 1.050, validation acc: 0.625
# Epoch 25, CIFAR-10 Batch 3:  Train cost: 0.890, train acc: 0.650, validation cost: 1.051, validation acc: 0.626
# Epoch 25, CIFAR-10 Batch 4:  Train cost: 0.992, train acc: 0.675, validation cost: 1.054, validation acc: 0.634
# Epoch 25, CIFAR-10 Batch 5:  Train cost: 0.930, train acc: 0.675, validation cost: 1.042, validation acc: 0.632
# Epoch 26, CIFAR-10 Batch 1:  Train cost: 0.976, train acc: 0.650, validation cost: 1.036, validation acc: 0.637
# Epoch 26, CIFAR-10 Batch 2:  Train cost: 1.051, train acc: 0.625, validation cost: 1.060, validation acc: 0.617
# Epoch 26, CIFAR-10 Batch 3:  Train cost: 0.882, train acc: 0.675, validation cost: 1.034, validation acc: 0.635
# Epoch 26, CIFAR-10 Batch 4:  Train cost: 0.957, train acc: 0.725, validation cost: 1.024, validation acc: 0.644
# Epoch 26, CIFAR-10 Batch 5:  Train cost: 0.923, train acc: 0.675, validation cost: 1.024, validation acc: 0.639
# Epoch 27, CIFAR-10 Batch 1:  Train cost: 1.007, train acc: 0.675, validation cost: 1.032, validation acc: 0.637
# Epoch 27, CIFAR-10 Batch 2:  Train cost: 0.973, train acc: 0.675, validation cost: 1.039, validation acc: 0.635
# Epoch 27, CIFAR-10 Batch 3:  Train cost: 0.875, train acc: 0.650, validation cost: 1.047, validation acc: 0.630
# Epoch 27, CIFAR-10 Batch 4:  Train cost: 0.914, train acc: 0.675, validation cost: 1.018, validation acc: 0.648
# Epoch 27, CIFAR-10 Batch 5:  Train cost: 0.864, train acc: 0.725, validation cost: 1.012, validation acc: 0.646
# Epoch 28, CIFAR-10 Batch 1:  Train cost: 0.943, train acc: 0.650, validation cost: 1.013, validation acc: 0.646
# Epoch 28, CIFAR-10 Batch 2:  Train cost: 1.068, train acc: 0.625, validation cost: 1.048, validation acc: 0.629
# Epoch 28, CIFAR-10 Batch 3:  Train cost: 0.833, train acc: 0.725, validation cost: 1.013, validation acc: 0.648
# Epoch 28, CIFAR-10 Batch 4:  Train cost: 0.939, train acc: 0.700, validation cost: 1.030, validation acc: 0.642
# Epoch 28, CIFAR-10 Batch 5:  Train cost: 0.929, train acc: 0.725, validation cost: 1.046, validation acc: 0.630
# Epoch 29, CIFAR-10 Batch 1:  Train cost: 0.888, train acc: 0.675, validation cost: 0.994, validation acc: 0.657
# Epoch 29, CIFAR-10 Batch 2:  Train cost: 0.964, train acc: 0.650, validation cost: 1.016, validation acc: 0.640
# Epoch 29, CIFAR-10 Batch 3:  Train cost: 0.859, train acc: 0.675, validation cost: 1.020, validation acc: 0.637
# Epoch 29, CIFAR-10 Batch 4:  Train cost: 0.983, train acc: 0.650, validation cost: 1.014, validation acc: 0.643
# Epoch 29, CIFAR-10 Batch 5:  Train cost: 0.889, train acc: 0.725, validation cost: 1.011, validation acc: 0.641
# Epoch 30, CIFAR-10 Batch 1:  Train cost: 0.905, train acc: 0.650, validation cost: 1.008, validation acc: 0.650
# Epoch 30, CIFAR-10 Batch 2:  Train cost: 0.944, train acc: 0.700, validation cost: 1.016, validation acc: 0.647
# Epoch 30, CIFAR-10 Batch 3:  Train cost: 0.779, train acc: 0.725, validation cost: 1.008, validation acc: 0.642
# Epoch 30, CIFAR-10 Batch 4:  Train cost: 0.928, train acc: 0.675, validation cost: 1.014, validation acc: 0.646
# Epoch 30, CIFAR-10 Batch 5:  Train cost: 0.935, train acc: 0.675, validation cost: 1.062, validation acc: 0.621
# Epoch 31, CIFAR-10 Batch 1:  Train cost: 0.876, train acc: 0.675, validation cost: 0.994, validation acc: 0.653
# Epoch 31, CIFAR-10 Batch 2:  Train cost: 0.854, train acc: 0.725, validation cost: 0.994, validation acc: 0.648
# Epoch 31, CIFAR-10 Batch 3:  Train cost: 0.808, train acc: 0.675, validation cost: 0.997, validation acc: 0.650
# Epoch 31, CIFAR-10 Batch 4:  Train cost: 0.945, train acc: 0.700, validation cost: 0.995, validation acc: 0.655
# Epoch 31, CIFAR-10 Batch 5:  Train cost: 0.856, train acc: 0.700, validation cost: 1.005, validation acc: 0.644
# Epoch 32, CIFAR-10 Batch 1:  Train cost: 0.891, train acc: 0.650, validation cost: 1.008, validation acc: 0.646
# Epoch 32, CIFAR-10 Batch 2:  Train cost: 0.942, train acc: 0.700, validation cost: 1.013, validation acc: 0.644
# Epoch 32, CIFAR-10 Batch 3:  Train cost: 0.767, train acc: 0.800, validation cost: 0.983, validation acc: 0.651
# Epoch 32, CIFAR-10 Batch 4:  Train cost: 0.946, train acc: 0.675, validation cost: 1.016, validation acc: 0.647
# Epoch 32, CIFAR-10 Batch 5:  Train cost: 0.858, train acc: 0.700, validation cost: 1.006, validation acc: 0.646
# Epoch 33, CIFAR-10 Batch 1:  Train cost: 0.929, train acc: 0.650, validation cost: 1.007, validation acc: 0.644
# Epoch 33, CIFAR-10 Batch 2:  Train cost: 0.849, train acc: 0.775, validation cost: 1.007, validation acc: 0.643
# Epoch 33, CIFAR-10 Batch 3:  Train cost: 0.766, train acc: 0.750, validation cost: 1.003, validation acc: 0.644
# Epoch 33, CIFAR-10 Batch 4:  Train cost: 0.871, train acc: 0.725, validation cost: 0.975, validation acc: 0.662
# Epoch 33, CIFAR-10 Batch 5:  Train cost: 0.818, train acc: 0.800, validation cost: 0.974, validation acc: 0.656
# Epoch 34, CIFAR-10 Batch 1:  Train cost: 0.861, train acc: 0.700, validation cost: 0.979, validation acc: 0.655
# Epoch 34, CIFAR-10 Batch 2:  Train cost: 0.911, train acc: 0.750, validation cost: 1.028, validation acc: 0.637
# Epoch 34, CIFAR-10 Batch 3:  Train cost: 0.762, train acc: 0.750, validation cost: 0.990, validation acc: 0.658
# Epoch 34, CIFAR-10 Batch 4:  Train cost: 0.942, train acc: 0.650, validation cost: 1.040, validation acc: 0.637
# Epoch 34, CIFAR-10 Batch 5:  Train cost: 0.849, train acc: 0.800, validation cost: 0.987, validation acc: 0.656
# Epoch 35, CIFAR-10 Batch 1:  Train cost: 0.893, train acc: 0.650, validation cost: 0.977, validation acc: 0.659
# Epoch 35, CIFAR-10 Batch 2:  Train cost: 0.912, train acc: 0.700, validation cost: 0.990, validation acc: 0.644
# Epoch 35, CIFAR-10 Batch 3:  Train cost: 0.730, train acc: 0.800, validation cost: 0.978, validation acc: 0.662
# Epoch 35, CIFAR-10 Batch 4:  Train cost: 0.947, train acc: 0.625, validation cost: 0.999, validation acc: 0.648
# Epoch 35, CIFAR-10 Batch 5:  Train cost: 0.841, train acc: 0.700, validation cost: 0.991, validation acc: 0.649
# Epoch 36, CIFAR-10 Batch 1:  Train cost: 0.841, train acc: 0.700, validation cost: 0.970, validation acc: 0.657
# Epoch 36, CIFAR-10 Batch 2:  Train cost: 0.784, train acc: 0.700, validation cost: 0.973, validation acc: 0.660
# Epoch 36, CIFAR-10 Batch 3:  Train cost: 0.732, train acc: 0.775, validation cost: 0.978, validation acc: 0.662
# Epoch 36, CIFAR-10 Batch 4:  Train cost: 0.913, train acc: 0.750, validation cost: 0.989, validation acc: 0.656
# Epoch 36, CIFAR-10 Batch 5:  Train cost: 0.814, train acc: 0.825, validation cost: 0.971, validation acc: 0.657
# Epoch 37, CIFAR-10 Batch 1:  Train cost: 0.853, train acc: 0.750, validation cost: 0.978, validation acc: 0.656
# Epoch 37, CIFAR-10 Batch 2:  Train cost: 0.868, train acc: 0.750, validation cost: 0.975, validation acc: 0.656
# Epoch 37, CIFAR-10 Batch 3:  Train cost: 0.739, train acc: 0.750, validation cost: 0.961, validation acc: 0.666
# Epoch 37, CIFAR-10 Batch 4:  Train cost: 0.892, train acc: 0.725, validation cost: 0.985, validation acc: 0.658
# Epoch 37, CIFAR-10 Batch 5:  Train cost: 0.863, train acc: 0.725, validation cost: 1.029, validation acc: 0.635
# Epoch 38, CIFAR-10 Batch 1:  Train cost: 0.908, train acc: 0.675, validation cost: 1.016, validation acc: 0.636
# Epoch 38, CIFAR-10 Batch 2:  Train cost: 0.845, train acc: 0.700, validation cost: 0.977, validation acc: 0.658
# Epoch 38, CIFAR-10 Batch 3:  Train cost: 0.743, train acc: 0.750, validation cost: 0.968, validation acc: 0.666
# Epoch 38, CIFAR-10 Batch 4:  Train cost: 0.913, train acc: 0.725, validation cost: 0.974, validation acc: 0.665
# Epoch 38, CIFAR-10 Batch 5:  Train cost: 0.807, train acc: 0.700, validation cost: 0.997, validation acc: 0.650
# Epoch 39, CIFAR-10 Batch 1:  Train cost: 0.876, train acc: 0.725, validation cost: 0.994, validation acc: 0.649
# Epoch 39, CIFAR-10 Batch 2:  Train cost: 0.891, train acc: 0.700, validation cost: 0.974, validation acc: 0.653
# Epoch 39, CIFAR-10 Batch 3:  Train cost: 0.784, train acc: 0.700, validation cost: 1.009, validation acc: 0.645
# Epoch 39, CIFAR-10 Batch 4:  Train cost: 0.989, train acc: 0.650, validation cost: 1.016, validation acc: 0.643
# Epoch 39, CIFAR-10 Batch 5:  Train cost: 0.765, train acc: 0.750, validation cost: 0.963, validation acc: 0.663
# Epoch 40, CIFAR-10 Batch 1:  Train cost: 0.867, train acc: 0.700, validation cost: 0.974, validation acc: 0.658
# Epoch 40, CIFAR-10 Batch 2:  Train cost: 0.780, train acc: 0.775, validation cost: 1.007, validation acc: 0.645
# Epoch 40, CIFAR-10 Batch 3:  Train cost: 0.770, train acc: 0.725, validation cost: 1.005, validation acc: 0.645
# Epoch 40, CIFAR-10 Batch 4:  Train cost: 0.901, train acc: 0.675, validation cost: 0.970, validation acc: 0.662
# Epoch 40, CIFAR-10 Batch 5:  Train cost: 0.825, train acc: 0.725, validation cost: 0.976, validation acc: 0.656

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.647745253164557

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
